# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv',header=1)

# %%
dataset.head()
# Out:
#    2  6  2012  29  61  13   1.3  64.4  4.1   7.6  1.0   3.9  0.4  not fire     \
# 0  3  6  2012  26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire
# 1  4  6  2012  25  89  13   2.5  28.6  1.3   6.9  0.0   1.7  0.0  not fire
# 2  5  6  2012  27  77  16   0.0  64.8  3.0  14.2  1.2   3.9  0.5  not fire
# 3  6  6  2012  31  67  14   0.0  82.6  5.8  22.2  3.1   7.0  2.5      fire
# 4  7  6  2012  33  54  13   0.0  88.2  9.9  30.5  6.4  10.9  7.2      fire
#
#    0  0.0
# 0  0  0.0
# 1  0  NaN
# 2  0  NaN
# 3  0  NaN
# 4  0  NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   2            241 non-null    int64
#  1   6            241 non-null    int64
#  2   2012         241 non-null    int64
#  3   29           241 non-null    int64
#  4   61           241 non-null    int64
#  5   13           241 non-null    int64
#  6   1.3          241 non-null    float64
#  7   64.4         241 non-null    float64
#  8   4.1          241 non-null    float64
#  9   7.6          241 non-null    float64
#  10  1.0          241 non-null    float64
#  11  3.9          241 non-null    float64
#  12  0.4          241 non-null    float64
#  13  not fire     241 non-null    object
#  14  0            241 non-null    int64
#  15  0.0          1 non-null      float64
# dtypes: float64(8), int64(7), object(1)
# memory usage: 30.3+ KB

# %%
##Data cleaning
##Check missing values
dataset[dataset.isnull().any(axis=1)]
# Out:
#       2  6  2012  29  61  13  1.3  64.4   4.1   7.6  1.0   3.9  0.4  \
# 1     4  6  2012  25  89  13  2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 2     5  6  2012  27  77  16  0.0  64.8   3.0  14.2  1.2   3.9  0.5
# 3     6  6  2012  31  67  14  0.0  82.6   5.8  22.2  3.1   7.0  2.5
# 4     7  6  2012  33  54  13  0.0  88.2   9.9  30.5  6.4  10.9  7.2
# 5     8  6  2012  30  73  15  0.0  86.6  12.1  38.3  5.6  13.5  7.1
# ..   .. ..   ...  ..  ..  ..  ...   ...   ...   ...  ...   ...  ...
# 236  26  9  2012  30  65  14  0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 237  27  9  2012  28  87  15  4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 238  28  9  2012  27  87  29  0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 239  29  9  2012  24  54  18  0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 240  30  9  2012  24  64  15  0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#       not fire     0  0.0
# 1     not fire     0  NaN
# 2     not fire     0  NaN
# 3         fire     0  NaN
# 4         fire     0  NaN
# ...

# %%
dataset.loc[:1,"Region"]=0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   2            241 non-null    int64
#  1   6            241 non-null    int64
#  2   2012         241 non-null    int64
#  3   29           241 non-null    int64
#  4   61           241 non-null    int64
#  5   13           241 non-null    int64
#  6   1.3          241 non-null    float64
#  7   64.4         241 non-null    float64
#  8   4.1          241 non-null    float64
#  9   7.6          241 non-null    float64
#  10  1.0          241 non-null    float64
#  11  3.9          241 non-null    float64
#  12  0.4          241 non-null    float64
#  13  not fire     241 non-null    object
#  14  0            241 non-null    int64
#  15  0.0          1 non-null      float64
#  16  Region       2 non-null      float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 32.1+ KB

# %%
##Data cleaning
##Check missing values
dataset[dataset.isnull().any(axis=1)]
# Out:
#       2  6  2012  29  61  13  1.3  64.4   4.1   7.6  1.0   3.9  0.4  \
# 1     4  6  2012  25  89  13  2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 2     5  6  2012  27  77  16  0.0  64.8   3.0  14.2  1.2   3.9  0.5
# 3     6  6  2012  31  67  14  0.0  82.6   5.8  22.2  3.1   7.0  2.5
# 4     7  6  2012  33  54  13  0.0  88.2   9.9  30.5  6.4  10.9  7.2
# 5     8  6  2012  30  73  15  0.0  86.6  12.1  38.3  5.6  13.5  7.1
# ..   .. ..   ...  ..  ..  ..  ...   ...   ...   ...  ...   ...  ...
# 236  26  9  2012  30  65  14  0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 237  27  9  2012  28  87  15  4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 238  28  9  2012  27  87  29  0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 239  29  9  2012  24  54  18  0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 240  30  9  2012  24  64  15  0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#       not fire     0  0.0  Region
# 1     not fire     0  NaN     0.0
# 2     not fire     0  NaN     NaN
# 3         fire     0  NaN     NaN
# ...

# %%
dataset.isnull()
# Out:
#          2      6   2012     29     61     13    1.3   64.4    4.1    7.6  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 236  False  False  False  False  False  False  False  False  False  False
# 237  False  False  False  False  False  False  False  False  False  False
# 238  False  False  False  False  False  False  False  False  False  False
# 239  False  False  False  False  False  False  False  False  False  False
# 240  False  False  False  False  False  False  False  False  False  False
#
#        1.0    3.9    0.4  not fire         0    0.0  Region
# ...

# %%
df=dataset

# %%
df.isnull().sum()
# Out:
# 2                0
# 6                0
# 2012             0
# 29               0
# 61               0
# 13               0
# 1.3              0
# 64.4             0
# 4.1              0
# 7.6              0
# 1.0              0
# 3.9              0
# 0.4              0
# not fire         0
# 0                0
# 0.0            240
# Region         239
# dtype: int64

# %%
df.dropna().reset_index(drop=True)
# Out:
#    2  6  2012  29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4  not fire     \
# 0  3  6  2012  26  82  22  13.1  47.1  2.5  7.1  0.3  2.7  0.1  not fire
#
#    0  0.0  Region
# 0  0  0.0     0.0

# %%
df.isnull().sum()
# Out:
# 2                0
# 6                0
# 2012             0
# 29               0
# 61               0
# 13               0
# 1.3              0
# 64.4             0
# 4.1              0
# 7.6              0
# 1.0              0
# 3.9              0
# 0.4              0
# not fire         0
# 0                0
# 0.0            240
# Region         239
# dtype: int64

# %%
df.columns
# Out:
# Index(['2', '6', '2012', '29', '61', '13', '1.3', '64.4', '4.1', '7.6', '1.0',
#        '3.9', '0.4', 'not fire   ', '0', '0.0', 'Region'],
#       dtype='object')

# %%
##fix spaces in column name
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['2', '6', '2012', '29', '61', '13', '1.3', '64.4', '4.1', '7.6', '1.0',
#        '3.9', '0.4', 'not fire', '0', '0.0', 'Region'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['2', '6', '2012', '29', '61', '13', '1.3', '64.4', '4.1', '7.6', '1.0',
#        '3.9', '0.4', 'not fire', '0', '0.0', 'Region'],
#       dtype='object')

# %%
##Changes the required columns as integer dt
df[['6','2','2012','29','61','13']]=df[['6','2','2012','29','61','13']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   2         241 non-null    int64
#  1   6         241 non-null    int64
#  2   2012      241 non-null    int64
#  3   29        241 non-null    int64
#  4   61        241 non-null    int64
#  5   13        241 non-null    int64
#  6   1.3       241 non-null    float64
#  7   64.4      241 non-null    float64
#  8   4.1       241 non-null    float64
#  9   7.6       241 non-null    float64
#  10  1.0       241 non-null    float64
#  11  3.9       241 non-null    float64
#  12  0.4       241 non-null    float64
#  13  not fire  241 non-null    object
#  14  0         241 non-null    int64
#  15  0.0       1 non-null      float64
#  16  Region    2 non-null      float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 32.1+ KB

# %%
##Changing the other columns into float data type
objects=[features for features in df.columns if df[features].dtypes=='o']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   2         241 non-null    int64
#  1   6         241 non-null    int64
#  2   2012      241 non-null    int64
#  3   29        241 non-null    int64
#  4   61        241 non-null    int64
#  5   13        241 non-null    int64
#  6   1.3       241 non-null    float64
#  7   64.4      241 non-null    float64
#  8   4.1       241 non-null    float64
#  9   7.6       241 non-null    float64
#  10  1.0       241 non-null    float64
#  11  3.9       241 non-null    float64
#  12  0.4       241 non-null    float64
#  13  not fire  241 non-null    object
#  14  0         241 non-null    int64
#  15  0.0       1 non-null      float64
#  16  Region    2 non-null      float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 32.1+ KB

# %%
df.describe()
# Out:
#                 2           6    2012          29          61          13  \
# count  241.000000  241.000000   241.0  241.000000  241.000000  241.000000
# mean    15.879668    7.514523  2012.0   32.178423   62.066390   15.493776
# std      8.782442    1.110929     0.0    3.631648   14.886087    2.813835
# min      1.000000    6.000000  2012.0   22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0   30.000000   52.000000   14.000000
# 50%     16.000000    8.000000  2012.0   32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0   35.000000   74.000000   17.000000
# max     31.000000    9.000000  2012.0   42.000000   90.000000   29.000000
#
#               1.3        64.4         4.1         7.6         1.0         3.9  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     0.763900   77.948548   14.771369   49.778008    4.772199   16.798755
# ...

# %%
df.head()
# Out:
#    2  6  2012  29  61  13   1.3  64.4  4.1   7.6  1.0   3.9  0.4     not fire  \
# 0  3  6  2012  26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire
# 1  4  6  2012  25  89  13   2.5  28.6  1.3   6.9  0.0   1.7  0.0  not fire
# 2  5  6  2012  27  77  16   0.0  64.8  3.0  14.2  1.2   3.9  0.5  not fire
# 3  6  6  2012  31  67  14   0.0  82.6  5.8  22.2  3.1   7.0  2.5      fire
# 4  7  6  2012  33  54  13   0.0  88.2  9.9  30.5  6.4  10.9  7.2      fire
#
#    0  0.0  Region
# 0  0  0.0     0.0
# 1  0  NaN     0.0
# 2  0  NaN     NaN
# 3  0  NaN     NaN
# 4  0  NaN     NaN

# %%
##Let's have the cleaned dataset
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv',index=False)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df_copy=df

# %%
df.columns
# Out:
# Index(['2', '6', '2012', '29', '61', '13', '1.3', '64.4', '4.1', '7.6', '1.0',
#        '3.9', '0.4', 'not fire', '0', '0.0', 'Region'],
#       dtype='object')

# %%
##drop columns
df_copy=df.drop(['2','6','2012'],axis=1)

# %%
df_copy.head()
# Out:
#    29  57  18     0  65.7  3.4   7.6  1.3  3.4.1  0.5     not fire  0.1  \
# 0  29  61  13   1.3  64.4  4.1   7.6  1.0    3.9  0.4  not fire       0
# 1  26  82  22  13.1  47.1  2.5   7.1  0.3    2.7  0.1  not fire       0
# 2  25  89  13   2.5  28.6  1.3   6.9  0.0    1.7  0.0  not fire       0
# 3  27  77  16   0.0  64.8  3.0  14.2  1.2    3.9  0.5  not fire       0
# 4  31  67  14   0.0  82.6  5.8  22.2  3.1    7.0  2.5      fire       0
#
#    Region
# 0     0.0
# 1     0.0
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df_copy['not fire'].value_counts()
# Out:
# not fire
# 1    240
# 0      2
# Name: count, dtype: int64

# %%
##Encoding of the categories in classes
df_copy['not fire']=np.where(df_copy['not fire']=='not fire',0,1)

# %%
df_copy.tail()
# Out:
#      29  61  13  1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire  0  0.0  \
# 236  30  65  14  0.0  85.4  16.0  44.5  4.5  16.9  6.5         1  1  NaN
# 237  28  87  15  4.4  41.1   6.5   8.0  0.1   6.2  0.0         1  1  NaN
# 238  27  87  29  0.5  45.9   3.5   7.9  0.4   3.4  0.2         1  1  NaN
# 239  24  54  18  0.1  79.7   4.3  15.2  1.7   5.1  0.7         1  1  NaN
# 240  24  64  15  0.2  67.3   3.8  16.5  1.2   4.8  0.5         1  1  NaN
#
#      Region
# 236     NaN
# 237     NaN
# 238     NaN
# 239     NaN
# 240     NaN

# %%
df_copy['not fire'].value_counts()
# Out:
# not fire
# 1    239
# 0      2
# Name: count, dtype: int64

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# !pip install --upgrade seaborn matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.0 MB 2.5 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.0 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 3.2 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.0 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.0 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.2
#     Uninstalling matplotlib-3.9.2:
# ...

# %%
##Plot density plot for all features
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
plt.style.use("seaborn")
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\admin\OneDrive\Desktop\Lipita.ipynb\myenv\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File c:\Users\admin\OneDrive\Desktop\Lipita.ipynb\myenv\Lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File c:\Users\admin\OneDrive\Desktop\Lipita.ipynb\myenv\Lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
# ...

# %%
##Percentage for pie chart
percentage=df_copy['not fire'].value_counts(normalize=True)*100

# %%
##Plotting piechart
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()

# %%
##Correlation
df_copy.corr()
# Out:
#                 29        61        13       1.3      64.4       4.1  \
# 29        1.000000 -0.655113 -0.286330 -0.328080  0.674474  0.482383
# 61       -0.655113  1.000000  0.245910  0.222053 -0.648665 -0.411498
# 13       -0.286330  0.245910  1.000000  0.174541 -0.167971 -0.000501
# 1.3      -0.328080  0.222053  0.174541  1.000000 -0.546264 -0.290336
# 64.4      0.674474 -0.648665 -0.167971 -0.546264  1.000000  0.601011
# 4.1       0.482383 -0.411498 -0.000501 -0.290336  0.601011  1.000000
# 7.6       0.372295 -0.229235  0.079667 -0.299532  0.504169  0.875122
# 1.0       0.601378 -0.690435  0.008335 -0.349041  0.738325  0.678426
# 3.9       0.456186 -0.356767  0.031800 -0.301522  0.589228  0.982133
# 0.4       0.563876 -0.584519  0.032547 -0.326031  0.689091  0.875056
# not fire  0.181194 -0.128909 -0.081647 -0.578381  0.232650  0.074429
# 0         0.264279 -0.406156 -0.182489 -0.040666  0.216467  0.186154
# 0.0            NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
df_copy.columns
# Out:
# Index(['29', '61', '13', '1.3', '64.4', '4.1', '7.6', '1.0', '3.9', '0.4',
#        'not fire', '0', '0.0', 'Region'],
#       dtype='object')

# %%
##Box Plots
sns.boxplot(df['0.4'],color='green')
# Out:
# <Axes: ylabel='0.4'>

# %%
df.head()
# Out:
#    2  6  2012  29  61  13   1.3  64.4  4.1   7.6  1.0   3.9  0.4     not fire  \
# 0  3  6  2012  26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire
# 1  4  6  2012  25  89  13   2.5  28.6  1.3   6.9  0.0   1.7  0.0  not fire
# 2  5  6  2012  27  77  16   0.0  64.8  3.0  14.2  1.2   3.9  0.5  not fire
# 3  6  6  2012  31  67  14   0.0  82.6  5.8  22.2  3.1   7.0  2.5      fire
# 4  7  6  2012  33  54  13   0.0  88.2  9.9  30.5  6.4  10.9  7.2      fire
#
#    0  0.0  Region
# 0  0  0.0     0.0
# 1  0  NaN     0.0
# 2  0  NaN     NaN
# 3  0  NaN     NaN
# 4  0  NaN     NaN

# %%
df['not fire']=np.where(df['not fire'],0,1)

# %%
##Monthly Fire Analysis
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='6',hue='not fire',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Bejala Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Bejala Regions')
